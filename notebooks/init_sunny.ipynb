# %%
import random

import pandas as pd
import numpy as np
from sklearn import preprocessing
from sklearn import feature_selection
from sklearn.model_selection import train_test_split
import statsmodels.api as sm
from sklearn.linear_model import LinearRegression
from sklearn.metrics import median_absolute_error
from sklearn.model_selection import cross_val_score
import warnings
warnings.simplefilter('ignore')

# %%
# obtains data, gets the head of the data
data = pd.read_csv("../data/data_cleaned.csv")
data
# Out:
#        Age Nationality  Overall  Potential                 Club   Value  \
# 0       31   Argentina       94         94         FC Barcelona  110.50
# 1       33    Portugal       94         94             Juventus   77.00
# 2       26      Brazil       92         93  Paris Saint-Germain  118.50
# 3       27       Spain       91         93    Manchester United   72.00
# 4       27     Belgium       91         92      Manchester City  102.00
# ...    ...         ...      ...        ...                  ...     ...
# 17902   19     England       47         65      Crewe Alexandra    0.06
# 17903   19      Sweden       47         63       Trelleborgs FF    0.06
# 17904   16     England       47         67     Cambridge United    0.06
# 17905   17     England       47         66      Tranmere Rovers    0.06
# 17906   16     England       46         66      Tranmere Rovers    0.06
#
#         Wage  Special Preferred_Foot  International_Reputation  ...  \
# 0      0.565     2202           Left                       5.0  ...
# 1      0.405     2228          Right                       5.0  ...
# 2      0.290     2143          Right                       5.0  ...
# 3      0.260     1471          Right                       4.0  ...
# 4      0.355     2281          Right                       4.0  ...
# ...      ...      ...            ...                       ...  ...
# 17902  0.001     1307          Right                       1.0  ...
# 17903  0.001     1098          Right                       1.0  ...
# 17904  0.001     1189          Right                       1.0  ...
# 17905  0.001     1228          Right                       1.0  ...
# 17906  0.001     1321          Right                       1.0  ...
#
#        GKReflexes  Release_Clause League_Country League_Level_Pyramid  \
# 0             8.0         226.500          Spain                  1.0
# 1            11.0         127.100          Italy                  1.0
# 2            11.0         228.100         France                  1.0
# 3            94.0         138.600        England                  1.0
# 4            13.0         196.400        England                  1.0
# ...           ...             ...            ...                  ...
# 17902         9.0           0.143        England                  4.0
# 17903        12.0           0.113         Sweden                  1.0
# 17904        13.0           0.165        England                  4.0
# 17905         9.0           0.143        England                  4.0
# 17906         9.0           0.165        England                  4.0
#
#        League_Revenue  League_Revenue_Per_Team  Is_Goalkeeper  Loaned_Out  \
# 0              4479.0                   223.95              0           0
# 1              2163.0                   108.20              0           0
# 2              1692.0                    84.60              0           0
# 3              6562.0                   328.10              1           0
# 4              6562.0                   328.10              0           0
# ...               ...                      ...            ...         ...
# 17902           106.0                     4.40              0           0
# 17903           145.0                     9.10              0           0
# 17904           106.0                     4.40              0           0
# 17905           106.0                     4.40              0           0
# 17906           106.0                     4.40              0           0
#
#        Off_Work_Rate  Def_Work_Rate
# 0             Medium         Medium
# 1               High            Low
# 2               High         Medium
# 3             Medium         Medium
# 4               High           High
# ...              ...            ...
# 17902         Medium         Medium
# 17903         Medium         Medium
# 17904         Medium         Medium
# 17905         Medium         Medium
# 17906         Medium         Medium
#
# [17907 rows x 86 columns]

# %%
# Converts nationality, club, preferred foot, position, real face, body type, loaded out
# Off_Work_Rate and Def_Work_Rate to numeric categories
cate = ["Nationality", "Club", "Preferred_Foot", "Real_Face", "Position"
        , "Loaned_Out", "Off_Work_Rate", "Def_Work_Rate", "League_Country"]
def cate_to_numeric(cate):
    data[cate] = data[cate].astype('category')
    data[cate] = data[cate].cat.codes

for cat in cate:
    cate_to_numeric(cat)

# %%
# Sorts release clause
data['Release_Clause'] = data['Release_Clause'].fillna(0)
data.loc[data.Release_Clause == 0,"has_release_clause"] = 0
data.loc[data.Release_Clause != 0,"has_release_clause"] = 1

# %%
# splits into training, testing, and validation data sets
y = data.pop('Value')
X = data

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.33,random_state=42)
X_train.head()
# Out:
#        Age  Nationality  Overall  Potential  Club   Wage  Special  \
# 2746    32          138       73         73   366  0.008     1875
# 10127   26           29       65         66   600  0.001     1792
# 6601    22          156       68         77   472  0.003     1675
# 5813    22          114       69         76   248  0.002     1115
# 14349   22           46       61         69   481  0.001     1632
#
#        Preferred_Foot  International_Reputation  Weak_Foot  ...  \
# 2746                1                       1.0        4.0  ...
# 10127               0                       1.0        3.0  ...
# 6601                1                       1.0        4.0  ...
# 5813                1                       1.0        3.0  ...
# 14349               1                       1.0        4.0  ...
#
#        Release_Clause  League_Country  League_Level_Pyramid  League_Revenue  \
# 2746            5.000              19                   1.0           509.0
# 10127           0.891               6                   1.0           113.0
# 6601            2.400              33                   1.0           851.0
# 5813            1.600              21                   1.0           152.0
# 14349           0.634              12                   3.0           171.0
#
#        League_Revenue_Per_Team  Is_Goalkeeper  Loaned_Out  Off_Work_Rate  \
# 2746                      28.0              0           0              2
# 10127                      6.3              0           0              0
# 6601                      38.7              0           0              0
# 5813                       9.5              1           0              2
# 14349                      7.1              0           0              2
#
#        Def_Work_Rate  has_release_clause
# 2746               2                 1.0
# 10127              2                 1.0
# 6601               2                 1.0
# 5813               2                 1.0
# 14349              2                 1.0
#
# [5 rows x 86 columns]

# %%
def stepwise_selection(X, y, end_thres=0.05, add_thres = 0.01):
    '''
    Function for stepwise regression. Code based on 
    https://datascience.stackexchange.com/questions/24405/how-to-do-stepwise-regression-using-sklearn
    while finding sklearn of stepwise regression.
    '''
    to_include = []
    while True:
        changed=False
        excluded = list(set(X.columns)-set(to_include))
        best_p_val = 1
        for new_column in excluded:
            model = sm.OLS(y, sm.add_constant(pd.DataFrame(X[to_include+[new_column]]))).fit()
            if model.pvalues[new_column] < best_p_val:
                best_p_val = model.pvalues[new_column]
                best_feature = new_column
        if best_p_val < add_thres:
            to_include.append(best_feature)
            changed=True
            
        model = sm.OLS(y, sm.add_constant(pd.DataFrame(X[to_include]))).fit()
        pvalues = model.pvalues.iloc[1:]
        if any(pvalues > end_thres):
            changed=True
            worst_feature = pvalues.argmax()
            to_include.remove(worst_feature)
        if not changed:
            break
    return to_include

# %%
# Performs stepwise selection, displays variables to include
variables_to_include = stepwise_selection(X_train, y_train, end_thres=0.01, add_thres = 0.01)
variables_to_include
# Out:
# ['International_Reputation',
#  'Wage',
#  'Potential',
#  'Release_Clause',
#  'has_release_clause',
#  'League_Revenue',
#  'Overall',
#  'Age',
#  'League_Revenue_Per_Team',
#  'SlidingTackle',
#  'FKAccuracy',
#  'Position',
#  'Loaned_Out',
#  'Reactions',
#  'Marking']

# %%
# Fits model
fit_model = LinearRegression().fit(X_train[variables_to_include], y_train)

# %%
y_pred = fit_model.predict(X_train[variables_to_include])
median_absolute_error(y_train,y_pred)
# Out:
# 0.25855701448902124

# %%
# Does Cross Validation, uses negative median absolute error
scores = cross_val_score(fit_model, X_train[variables_to_include], 
                         y_train, cv=5, scoring = "neg_median_absolute_error")
print(scores)
print(np.mean(scores))
# Out:
# [-0.26784812 -0.25361988 -0.26195082 -0.25787879 -0.25687181]
# -0.2596338859458657

# %%
y_pred = fit_model.predict(X_test[variables_to_include])
median_absolute_error(y_test,y_pred)
# Out:
# 0.2521152721278188
